# %% [markdown]
# <a href="https://colab.research.google.com/github/cwlanyon/CardiacDTWorkshop/blob/main/EforCDC_Bonus_solutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bonus Emulators!
#
# In this workbook we'll introduce AutoEmulate, a python package in development by the turing institute that finds the best emulator for your data!
#
# https://www.autoemulate.com/
#
# We'll be emulating a dataset generated by running the Reaction-eikonal model of electrophysiology over a personalised patient cardiac mesh, generated via CT imaging. You can learn more about the model and the patient meshes here: https://journals.plos.org/ploscompbiol/article?id=10.1371/journal.pcbi.1008851

# %%
# !pip install AutoEmulate
# Out:
# Requirement already satisfied: AutoEmulate in /usr/local/lib/python3.12/dist-packages (1.1.1)
# Requirement already satisfied: mogp-emulator>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from AutoEmulate) (0.7.2)
# Requirement already satisfied: matplotlib>=3.7.2 in /usr/local/lib/python3.12/dist-packages (from AutoEmulate) (3.10.0)
# Requirement already satisfied: seaborn>=0.12.2 in /usr/local/lib/python3.12/dist-packages (from AutoEmulate) (0.13.2)
# Requirement already satisfied: scikit-learn<1.6.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from AutoEmulate) (1.5.2)
# Requirement already satisfied: pandas>=2.1 in /usr/local/lib/python3.12/dist-packages (from AutoEmulate) (2.2.2)
# Requirement already satisfied: torch>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from AutoEmulate) (2.8.0+cu126)
# Requirement already satisfied: skorch>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from AutoEmulate) (1.2.0)
# Requirement already satisfied: scipy>=1.11.3 in /usr/local/lib/python3.12/dist-packages (from AutoEmulate) (1.16.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from AutoEmulate) (2.0.2)
# Requirement already satisfied: joblib>=1.3.2 in /usr/local/lib/python3.12/dist-packages (from AutoEmulate) (1.5.2)
# Requirement already satisfied: tqdm>=4.66.2 in /usr/local/lib/python3.12/dist-packages (from AutoEmulate) (4.67.1)
# Requirement already satisfied: iprogress>=0.4 in /usr/local/lib/python3.12/dist-packages (from AutoEmulate) (0.4)
# Requirement already satisfied: lightgbm>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from AutoEmulate) (4.6.0)
# Requirement already satisfied: ipywidgets>=8.1.2 in /usr/local/lib/python3.12/dist-packages (from AutoEmulate) (8.1.7)
# Requirement already satisfied: gpytorch>=1.12 in /usr/local/lib/python3.12/dist-packages (from AutoEmulate) (1.14)
# Requirement already satisfied: salib>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from AutoEmulate) (1.5.1)
# Requirement already satisfied: torcheval>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from AutoEmulate) (0.0.7)
# Requirement already satisfied: anytree>=2.12.1 in /usr/local/lib/python3.12/dist-packages (from AutoEmulate) (2.13.0)
# Requirement already satisfied: torchmetrics>=1.7.1 in /usr/local/lib/python3.12/dist-packages (from AutoEmulate) (1.8.2)
# Requirement already satisfied: pyro-ppl>=1.9.1 in /usr/local/lib/python3.12/dist-packages (from AutoEmulate) (1.9.1)
# Requirement already satisfied: corner>=2.2.3 in /usr/local/lib/python3.12/dist-packages (from AutoEmulate) (2.2.3)
# Requirement already satisfied: torchrbf>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from AutoEmulate) (1.0.0)
# Requirement already satisfied: arviz>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from AutoEmulate) (0.22.0)
# Requirement already satisfied: getdist>=1.7.2 in /usr/local/lib/python3.12/dist-packages (from AutoEmulate) (1.7.3)
# Requirement already satisfied: setuptools>=60.0.0 in /usr/local/lib/python3.12/dist-packages (from arviz>=0.21.0->AutoEmulate) (75.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from arviz>=0.21.0->AutoEmulate) (25.0)
# Requirement already satisfied: xarray>=2023.7.0 in /usr/local/lib/python3.12/dist-packages (from arviz>=0.21.0->AutoEmulate) (2025.9.0)
# Requirement already satisfied: h5netcdf>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from arviz>=0.21.0->AutoEmulate) (1.6.4)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from arviz>=0.21.0->AutoEmulate) (4.15.0)
# Requirement already satisfied: xarray-einstats>=0.3 in /usr/local/lib/python3.12/dist-packages (from arviz>=0.21.0->AutoEmulate) (0.9.1)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.12/dist-packages (from getdist>=1.7.2->AutoEmulate) (6.0.2)
# Requirement already satisfied: jaxtyping in /usr/local/lib/python3.12/dist-packages (from gpytorch>=1.12->AutoEmulate) (0.3.3)
# Requirement already satisfied: mpmath<=1.3,>=0.19 in /usr/local/lib/python3.12/dist-packages (from gpytorch>=1.12->AutoEmulate) (1.3.0)
# Requirement already satisfied: linear-operator>=0.6 in /usr/local/lib/python3.12/dist-packages (from gpytorch>=1.12->AutoEmulate) (0.6)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from iprogress>=0.4->AutoEmulate) (1.17.0)
# Requirement already satisfied: comm>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=8.1.2->AutoEmulate) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=8.1.2->AutoEmulate) (7.34.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=8.1.2->AutoEmulate) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=8.1.2->AutoEmulate) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=8.1.2->AutoEmulate) (3.0.15)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.2->AutoEmulate) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.2->AutoEmulate) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.2->AutoEmulate) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.2->AutoEmulate) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.2->AutoEmulate) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.2->AutoEmulate) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.2->AutoEmulate) (2.9.0.post0)
# Requirement already satisfied: patsy in /usr/local/lib/python3.12/dist-packages (from mogp-emulator>=0.7.2->AutoEmulate) (1.0.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1->AutoEmulate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1->AutoEmulate) (2025.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from pyro-ppl>=1.9.1->AutoEmulate) (3.4.0)
# Requirement already satisfied: pyro-api>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from pyro-ppl>=1.9.1->AutoEmulate) (0.1.2)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from salib>=1.5.1->AutoEmulate) (0.70.16)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<1.6.0,>=1.3.0->AutoEmulate) (3.6.0)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.12/dist-packages (from skorch>=0.15.0->AutoEmulate) (0.9.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->AutoEmulate) (3.19.1)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->AutoEmulate) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->AutoEmulate) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->AutoEmulate) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->AutoEmulate) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->AutoEmulate) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->AutoEmulate) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->AutoEmulate) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->AutoEmulate) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->AutoEmulate) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->AutoEmulate) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->AutoEmulate) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->AutoEmulate) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->AutoEmulate) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->AutoEmulate) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->AutoEmulate) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->AutoEmulate) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->AutoEmulate) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->AutoEmulate) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->AutoEmulate) (3.4.0)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics>=1.7.1->AutoEmulate) (0.15.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from h5netcdf>=1.0.2->arviz>=0.21.0->AutoEmulate) (3.14.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.2->AutoEmulate) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.2->AutoEmulate) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.2->AutoEmulate) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.2->AutoEmulate) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.2->AutoEmulate) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.2->AutoEmulate) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.2->AutoEmulate) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.2->AutoEmulate) (4.9.0)
# Requirement already satisfied: wadler-lindig>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from jaxtyping->gpytorch>=1.12->AutoEmulate) (0.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.1.0->AutoEmulate) (3.0.2)
# Requirement already satisfied: dill>=0.3.8 in /usr/local/lib/python3.12/dist-packages (from multiprocess->salib>=1.5.1->AutoEmulate) (0.3.8)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8.1.2->AutoEmulate) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=8.1.2->AutoEmulate) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets>=8.1.2->AutoEmulate) (0.2.13)

# %%
# Load important modules
# Support for maths
import numpy as np
import torch

import pandas as pd

from autoemulate.core.compare import AutoEmulate # emulators

# Plotting tools
from matplotlib import pyplot as plt
# we use the following for plotting figures in jupyter
# %matplotlib inline

# For splitting training and testing data
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')

# Displaying images from URLs
from PIL import Image
from IPython.display import display
import urllib.request
from io import BytesIO

# %% [markdown]
# The Reaction-eikonal model simulates the propagation of electronic signals across the surface of the heart. In this example it was run over a personalised patient mesh from a cohort of meshes (see the figure below, we're using patient 1's cardiac mesh).

# %%
# Figure showing customised cardiac meshes.

url = 'https://journals.plos.org/ploscompbiol/article/figure/image?size=inline&id=10.1371/journal.pcbi.1008851.g002'
with urllib.request.urlopen(url) as url:
    img = Image.open(BytesIO(url.read()))

display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=320x282>

# %% [markdown]
# First let's load the data from github.

# %%
# Get data
# !wget https://raw.githubusercontent.com/cwlanyon/CardiacDTWorkshop/refs/heads/main/EP%20Data/X_EP.txt
# !wget https://raw.githubusercontent.com/cwlanyon/CardiacDTWorkshop/refs/heads/main/EP%20Data/Y.txt
# Get labels
# !wget https://raw.githubusercontent.com/cwlanyon/CardiacDTWorkshop/refs/heads/main/EP%20Data/ylabels.txt
# !wget https://raw.githubusercontent.com/cwlanyon/CardiacDTWorkshop/refs/heads/main/EP%20Data/xlabels_EP.txt
# Out:
# --2025-10-03 16:08:55--  https://raw.githubusercontent.com/cwlanyon/CardiacDTWorkshop/refs/heads/main/EP%20Data/X_EP.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9227 (9.0K) [text/plain]
# Saving to: ‘X_EP.txt.1’
#
# X_EP.txt.1          100%[===================>]   9.01K  --.-KB/s    in 0s
#
# 2025-10-03 16:08:55 (18.4 MB/s) - ‘X_EP.txt.1’ saved [9227/9227]
#
# --2025-10-03 16:08:55--  https://raw.githubusercontent.com/cwlanyon/CardiacDTWorkshop/refs/heads/main/EP%20Data/Y.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2836 (2.8K) [text/plain]
# Saving to: ‘Y.txt.1’
#
# Y.txt.1             100%[===================>]   2.77K  --.-KB/s    in 0s
#
# 2025-10-03 16:08:55 (37.4 MB/s) - ‘Y.txt.1’ saved [2836/2836]
#
# --2025-10-03 16:08:55--  https://raw.githubusercontent.com/cwlanyon/CardiacDTWorkshop/refs/heads/main/EP%20Data/ylabels.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12 [text/plain]
# Saving to: ‘ylabels.txt.1’
#
# ylabels.txt.1       100%[===================>]      12  --.-KB/s    in 0s
#
# 2025-10-03 16:08:55 (183 KB/s) - ‘ylabels.txt.1’ saved [12/12]
#
# --2025-10-03 16:08:55--  https://raw.githubusercontent.com/cwlanyon/CardiacDTWorkshop/refs/heads/main/EP%20Data/xlabels_EP.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 55 [text/plain]
# Saving to: ‘xlabels_EP.txt.1’
#
# xlabels_EP.txt.1    100%[===================>]      55  --.-KB/s    in 0s
#
# 2025-10-03 16:08:55 (2.89 MB/s) - ‘xlabels_EP.txt.1’ saved [55/55]

# %%
#Read the data into DataFrame objects

x_labels=pd.read_csv('/content/xlabels_EP.txt',index_col=None,delim_whitespace=True,header=None)
y_labels=pd.read_csv('/content/ylabels.txt',index_col=None,delim_whitespace=True,header=None)

x_all = pd.read_csv('/content/X_EP.txt',index_col=None,delim_whitespace=True,header=None)
y_all = pd.read_csv('/content/Y.txt',index_col=None,delim_whitespace=True,header=None)

x_all.columns=x_labels.values.squeeze()
y_all.columns=y_labels.values.squeeze()

# %% [markdown]
# The model has 6 inputs, two conduction velocities (CV) and 4 anisotropy ratios which modify the CVs in different areas of the heart. Below we print the top of the input dataframe to show the parameters.

# %%
x_all.head() # Show top 5 rows of input dataframe
# Out:
#    CV_ventricles  k_ventricles    k_FEC  CV_atria   k_atria     k_BB
# 0       0.487005      0.321104  6.56834  0.799039  0.470510  5.04917
# 1       0.649337      0.345380  4.40605  0.311586  0.313059  4.37368
# 2       0.666146      0.431970  7.48917  0.996915  0.203510  3.88357
# 3       0.564330      0.319989  4.09474  0.680346  0.313557  3.05286
# 4       0.519419      0.363704  6.37449  0.538744  0.226915  2.15749

# %% [markdown]
# Though the model simulates electrical signals across the surface of the entire heart, we summarise the model using the "total activation time", the total time it takes for a signal to move across the surface. We calculate this quantity for the atria and the ventricles. This leads to two model outputs, $A_{TAT}$ and $V_{TAT}$.

# %%
y_all.head() # show top 5 rows of output dataframe
# Out:
#      A_TAT     V_TAT
# 0  121.882  121.3370
# 1  344.083   90.1192
# 2  121.510   81.1778
# 3  165.531  106.5830
# 4  235.617  109.6840

# %% [markdown]
# To emulate the model using AutoEmulate we need to convert the dataframes into torch tensors with the float dtype.

# %%
# Convert dataframe to torch tensor
x =  torch.tensor(x_all.values, dtype=torch.float32)
y = torch.tensor(y_all.values, dtype=torch.float32)

# %%
# Use train_test_split to split into training and desting data
x_train, x_test, y_train, y_test = train_test_split(
    x, #inputs
    y, #outputs
    test_size=0.2, # proportion (or integer valued) of total data set used for testing
)

# %% [markdown]
# AutoEmulate automatically handles a lot of emulation decision making, it normalises the data, performs multiple train-test splits to test the robustness of the emulators to different training sets and creates output summaries. Below we generate an AutoEmulate object with our data.

# %%
ae = AutoEmulate(x_train, y_train, log_level="error") # intialises autoemulate object
# Out:
# INFO:autoemulate:Comparing ['GaussianProcess', 'GaussianProcessCorrelated', 'GaussianProcessMatern32', 'GaussianProcessMatern52', 'GaussianProcessRBF', 'RadialBasisFunctions', 'RandomForest', 'PolynomialRegression', 'MLP', 'EnsembleMLP', 'EnsembleMLPDropout']
# INFO:autoemulate:Running Model: GaussianProcess: 1/11 (attempt 1/3)
# DEBUG:autoemulate:Running tuner for model "GaussianProcess"
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# WARNING:autoemulate:Failed tuning iteration 0 with model params: {"mean_module_fn":"<function poly_mean at 0x7e6040505c60>","covar_module_fn":"<function matern_5_2_kernel at 0x7e6040504ea0>","epochs":200,"lr":0.05,"likelihood_cls":"<class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>","scheduler_cls":"<class 'torch.optim.lr_scheduler.LRScheduler'>","scheduler_kwargs":{"policy":"ReduceLROnPlateau","patience":5,"factor":0.5}}: The size of tensor a (6) must match the size of tensor b (2) at non-singleton dimension 2
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcess; iteration: 1/10; mean (std) r2=0.925 (0.024); model_params: {'mean_module_fn': <function linear_mean at 0x7e6040505620>, 'covar_module_fn': <function rbf_times_linear at 0x7e6040505300>, 'epochs': 50, 'lr': 0.05, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': <class 'torch.optim.lr_scheduler.ExponentialLR'>, 'scheduler_kwargs': {'gamma': 0.9}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcess; iteration: 2/10; mean (std) r2=0.754 (0.100); model_params: {'mean_module_fn': <function linear_mean at 0x7e6040505620>, 'covar_module_fn': <function rq_kernel at 0x7e6040504fe0>, 'epochs': 100, 'lr': 0.01, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': <class 'torch.optim.lr_scheduler.ExponentialLR'>, 'scheduler_kwargs': {'gamma': 0.95}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# WARNING:autoemulate:Failed tuning iteration 2 with model params: {"mean_module_fn":"<function poly_mean at 0x7e6040505c60>","covar_module_fn":"<function matern_5_2_plus_rq at 0x7e6040505260>","epochs":100,"lr":0.5,"likelihood_cls":"<class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>","scheduler_cls":"<class 'torch.optim.lr_scheduler.ExponentialLR'>","scheduler_kwargs":{"gamma":0.9}}: The size of tensor a (6) must match the size of tensor b (2) at non-singleton dimension 2
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcess; iteration: 3/10; mean (std) r2=0.996 (0.001); model_params: {'mean_module_fn': <function constant_mean at 0x7e6040505440>, 'covar_module_fn': <function matern_5_2_plus_rq at 0x7e6040505260>, 'epochs': 50, 'lr': 0.5, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': <class 'torch.optim.lr_scheduler.ExponentialLR'>, 'scheduler_kwargs': {'gamma': 0.9}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcess; iteration: 4/10; mean (std) r2=0.995 (0.002); model_params: {'mean_module_fn': <function linear_mean at 0x7e6040505620>, 'covar_module_fn': <function rq_kernel at 0x7e6040504fe0>, 'epochs': 200, 'lr': 0.05, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': <class 'torch.optim.lr_scheduler.ExponentialLR'>, 'scheduler_kwargs': {'gamma': 0.9}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcess; iteration: 5/10; mean (std) r2=0.900 (0.030); model_params: {'mean_module_fn': <function zero_mean at 0x7e6040505580>, 'covar_module_fn': <function rbf_times_linear at 0x7e6040505300>, 'epochs': 200, 'lr': 0.01, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': None, 'scheduler_kwargs': {}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# WARNING:autoemulate:Failed tuning iteration 5 with model params: {"mean_module_fn":"<function poly_mean at 0x7e6040505c60>","covar_module_fn":"<function rbf_plus_linear at 0x7e60405051c0>","epochs":200,"lr":0.1,"likelihood_cls":"<class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>","scheduler_cls":null,"scheduler_kwargs":{}}: The size of tensor a (6) must match the size of tensor b (2) at non-singleton dimension 2
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcess; iteration: 6/10; mean (std) r2=0.840 (0.061); model_params: {'mean_module_fn': <function constant_mean at 0x7e6040505440>, 'covar_module_fn': <function matern_3_2_kernel at 0x7e6040504f40>, 'epochs': 100, 'lr': 0.01, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': None, 'scheduler_kwargs': {}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcess; iteration: 7/10; mean (std) r2=0.979 (0.009); model_params: {'mean_module_fn': <function linear_mean at 0x7e6040505620>, 'covar_module_fn': <function rbf_times_linear at 0x7e6040505300>, 'epochs': 100, 'lr': 0.05, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': <class 'torch.optim.lr_scheduler.LRScheduler'>, 'scheduler_kwargs': {'policy': 'ReduceLROnPlateau', 'patience': 5, 'factor': 0.5}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcess; iteration: 8/10; mean (std) r2=0.995 (0.003); model_params: {'mean_module_fn': <function constant_mean at 0x7e6040505440>, 'covar_module_fn': <function rbf_times_linear at 0x7e6040505300>, 'epochs': 100, 'lr': 0.1, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': None, 'scheduler_kwargs': {}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# WARNING:autoemulate:Failed tuning iteration 8 with model params: {"mean_module_fn":"<function poly_mean at 0x7e6040505c60>","covar_module_fn":"<function matern_5_2_plus_rq at 0x7e6040505260>","epochs":200,"lr":0.01,"likelihood_cls":"<class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>","scheduler_cls":"<class 'torch.optim.lr_scheduler.ExponentialLR'>","scheduler_kwargs":{"gamma":0.95}}: The size of tensor a (6) must match the size of tensor b (2) at non-singleton dimension 2
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcess; iteration: 9/10; mean (std) r2=0.806 (0.039); model_params: {'mean_module_fn': <function zero_mean at 0x7e6040505580>, 'covar_module_fn': <function rq_kernel at 0x7e6040504fe0>, 'epochs': 50, 'lr': 0.01, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': None, 'scheduler_kwargs': {}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcess; iteration: 10/10; mean (std) r2=0.887 (0.017); model_params: {'mean_module_fn': <function linear_mean at 0x7e6040505620>, 'covar_module_fn': <function rbf_times_linear at 0x7e6040505300>, 'epochs': 100, 'lr': 0.01, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': None, 'scheduler_kwargs': {}}
# DEBUG:autoemulate:Tuner found best params for model "GaussianProcess": {'mean_module_fn': <function constant_mean at 0x7e6040505440>, 'covar_module_fn': <function matern_5_2_plus_rq at 0x7e6040505260>, 'epochs': 50, 'lr': 0.5, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': <class 'torch.optim.lr_scheduler.ExponentialLR'>, 'scheduler_kwargs': {'gamma': 0.9}} with score: 0.996
# DEBUG:autoemulate:Running cross-validation for model "GaussianProcess" for "10" iterations
# DEBUG:autoemulate:Cross-validation for model "GaussianProcess" completed with test mean (std) R2 score: 0.999 (0.001), mean (std) RMSE score: 1.568 (0.290)
# INFO:autoemulate:Finished running Model: GaussianProcess
#
# INFO:autoemulate:Running Model: GaussianProcessCorrelated: 2/11 (attempt 1/3)
# DEBUG:autoemulate:Running tuner for model "GaussianProcessCorrelated"
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcessCorrelated; iteration: 1/10; mean (std) r2=0.962 (0.024); model_params: {'mean_module_fn': <function zero_mean at 0x7e6040505580>, 'covar_module_fn': <function rq_kernel at 0x7e6040504fe0>, 'epochs': 200, 'lr': 0.5, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': None, 'scheduler_kwargs': {}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcessCorrelated; iteration: 2/10; mean (std) r2=0.982 (0.010); model_params: {'mean_module_fn': <function zero_mean at 0x7e6040505580>, 'covar_module_fn': <function matern_5_2_plus_rq at 0x7e6040505260>, 'epochs': 100, 'lr': 0.5, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': None, 'scheduler_kwargs': {}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcessCorrelated; iteration: 3/10; mean (std) r2=0.973 (0.007); model_params: {'mean_module_fn': <function constant_mean at 0x7e6040505440>, 'covar_module_fn': <function rbf_plus_constant at 0x7e6040505120>, 'epochs': 200, 'lr': 0.5, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': <class 'torch.optim.lr_scheduler.LRScheduler'>, 'scheduler_kwargs': {'policy': 'ReduceLROnPlateau', 'patience': 5, 'factor': 0.5}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# WARNING:autoemulate:Failed tuning iteration 3 with model params: {"mean_module_fn":"<function poly_mean at 0x7e6040505c60>","covar_module_fn":"<function rq_kernel at 0x7e6040504fe0>","epochs":100,"lr":0.01,"likelihood_cls":"<class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>","scheduler_cls":"<class 'torch.optim.lr_scheduler.LRScheduler'>","scheduler_kwargs":{"policy":"ReduceLROnPlateau","patience":5,"factor":0.5}}: The size of tensor a (6) must match the size of tensor b (2) at non-singleton dimension 2
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# WARNING:autoemulate:Failed tuning iteration 3 with model params: {"mean_module_fn":"<function poly_mean at 0x7e6040505c60>","covar_module_fn":"<function matern_3_2_kernel at 0x7e6040504f40>","epochs":50,"lr":0.1,"likelihood_cls":"<class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>","scheduler_cls":"<class 'torch.optim.lr_scheduler.ExponentialLR'>","scheduler_kwargs":{"gamma":0.9}}: The size of tensor a (6) must match the size of tensor b (2) at non-singleton dimension 2
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcessCorrelated; iteration: 4/10; mean (std) r2=0.953 (0.038); model_params: {'mean_module_fn': <function constant_mean at 0x7e6040505440>, 'covar_module_fn': <function rbf_plus_linear at 0x7e60405051c0>, 'epochs': 200, 'lr': 0.5, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': <class 'torch.optim.lr_scheduler.ExponentialLR'>, 'scheduler_kwargs': {'gamma': 0.95}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcessCorrelated; iteration: 5/10; mean (std) r2=0.774 (0.051); model_params: {'mean_module_fn': <function constant_mean at 0x7e6040505440>, 'covar_module_fn': <function matern_5_2_kernel at 0x7e6040504ea0>, 'epochs': 50, 'lr': 0.01, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': <class 'torch.optim.lr_scheduler.LRScheduler'>, 'scheduler_kwargs': {'policy': 'ReduceLROnPlateau', 'patience': 5, 'factor': 0.5}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcessCorrelated; iteration: 6/10; mean (std) r2=0.956 (0.020); model_params: {'mean_module_fn': <function constant_mean at 0x7e6040505440>, 'covar_module_fn': <function matern_3_2_kernel at 0x7e6040504f40>, 'epochs': 200, 'lr': 0.05, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': None, 'scheduler_kwargs': {}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcessCorrelated; iteration: 7/10; mean (std) r2=0.903 (0.030); model_params: {'mean_module_fn': <function linear_mean at 0x7e6040505620>, 'covar_module_fn': <function rbf_plus_linear at 0x7e60405051c0>, 'epochs': 100, 'lr': 0.01, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': <class 'torch.optim.lr_scheduler.LRScheduler'>, 'scheduler_kwargs': {'policy': 'ReduceLROnPlateau', 'patience': 5, 'factor': 0.5}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# WARNING:autoemulate:Failed tuning iteration 7 with model params: {"mean_module_fn":"<function poly_mean at 0x7e6040505c60>","covar_module_fn":"<function rq_kernel at 0x7e6040504fe0>","epochs":100,"lr":0.5,"likelihood_cls":"<class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>","scheduler_cls":null,"scheduler_kwargs":{}}: The size of tensor a (6) must match the size of tensor b (2) at non-singleton dimension 2
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# WARNING:autoemulate:Failed tuning iteration 7 with model params: {"mean_module_fn":"<function poly_mean at 0x7e6040505c60>","covar_module_fn":"<function matern_5_2_kernel at 0x7e6040504ea0>","epochs":50,"lr":0.5,"likelihood_cls":"<class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>","scheduler_cls":"<class 'torch.optim.lr_scheduler.LRScheduler'>","scheduler_kwargs":{"policy":"ReduceLROnPlateau","patience":5,"factor":0.5}}: The size of tensor a (6) must match the size of tensor b (2) at non-singleton dimension 2
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcessCorrelated; iteration: 8/10; mean (std) r2=0.971 (0.010); model_params: {'mean_module_fn': <function constant_mean at 0x7e6040505440>, 'covar_module_fn': <function rq_kernel at 0x7e6040504fe0>, 'epochs': 50, 'lr': 0.5, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': <class 'torch.optim.lr_scheduler.LRScheduler'>, 'scheduler_kwargs': {'policy': 'ReduceLROnPlateau', 'patience': 5, 'factor': 0.5}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcessCorrelated; iteration: 9/10; mean (std) r2=0.961 (0.012); model_params: {'mean_module_fn': <function zero_mean at 0x7e6040505580>, 'covar_module_fn': <function rbf at 0x7e6040504e00>, 'epochs': 50, 'lr': 0.1, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': <class 'torch.optim.lr_scheduler.LRScheduler'>, 'scheduler_kwargs': {'policy': 'ReduceLROnPlateau', 'patience': 5, 'factor': 0.5}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcessCorrelated; iteration: 10/10; mean (std) r2=0.911 (0.017); model_params: {'mean_module_fn': <function zero_mean at 0x7e6040505580>, 'covar_module_fn': <function rbf_times_linear at 0x7e6040505300>, 'epochs': 50, 'lr': 0.1, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': <class 'torch.optim.lr_scheduler.LRScheduler'>, 'scheduler_kwargs': {'policy': 'ReduceLROnPlateau', 'patience': 5, 'factor': 0.5}}
# DEBUG:autoemulate:Tuner found best params for model "GaussianProcessCorrelated": {'mean_module_fn': <function zero_mean at 0x7e6040505580>, 'covar_module_fn': <function matern_5_2_plus_rq at 0x7e6040505260>, 'epochs': 100, 'lr': 0.5, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': None, 'scheduler_kwargs': {}} with score: 0.982
# DEBUG:autoemulate:Running cross-validation for model "GaussianProcessCorrelated" for "10" iterations
# DEBUG:autoemulate:Cross-validation for model "GaussianProcessCorrelated" completed with test mean (std) R2 score: 0.997 (0.001), mean (std) RMSE score: 2.616 (0.319)
# INFO:autoemulate:Finished running Model: GaussianProcessCorrelated
#
# INFO:autoemulate:Running Model: GaussianProcessMatern32: 3/11 (attempt 1/3)
# DEBUG:autoemulate:Running tuner for model "GaussianProcessMatern32"
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcessMatern32; iteration: 1/10; mean (std) r2=0.965 (0.004); model_params: {'epochs': 50, 'lr': 0.1, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': <class 'torch.optim.lr_scheduler.ExponentialLR'>, 'scheduler_kwargs': {'gamma': 0.9}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcessMatern32; iteration: 2/10; mean (std) r2=0.987 (0.001); model_params: {'epochs': 100, 'lr': 0.1, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': <class 'torch.optim.lr_scheduler.ExponentialLR'>, 'scheduler_kwargs': {'gamma': 0.95}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcessMatern32; iteration: 3/10; mean (std) r2=0.995 (0.002); model_params: {'epochs': 100, 'lr': 0.5, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': <class 'torch.optim.lr_scheduler.LRScheduler'>, 'scheduler_kwargs': {'policy': 'ReduceLROnPlateau', 'patience': 5, 'factor': 0.5}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcessMatern32; iteration: 4/10; mean (std) r2=0.904 (0.042); model_params: {'epochs': 200, 'lr': 0.01, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': <class 'torch.optim.lr_scheduler.LRScheduler'>, 'scheduler_kwargs': {'policy': 'ReduceLROnPlateau', 'patience': 5, 'factor': 0.5}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcessMatern32; iteration: 5/10; mean (std) r2=0.995 (0.002); model_params: {'epochs': 200, 'lr': 0.5, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': None, 'scheduler_kwargs': {}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcessMatern32; iteration: 6/10; mean (std) r2=0.992 (0.005); model_params: {'epochs': 50, 'lr': 0.5, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': None, 'scheduler_kwargs': {}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcessMatern32; iteration: 7/10; mean (std) r2=0.989 (0.005); model_params: {'epochs': 200, 'lr': 0.1, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': <class 'torch.optim.lr_scheduler.ExponentialLR'>, 'scheduler_kwargs': {'gamma': 0.9}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcessMatern32; iteration: 8/10; mean (std) r2=0.994 (0.003); model_params: {'epochs': 50, 'lr': 0.5, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': <class 'torch.optim.lr_scheduler.LRScheduler'>, 'scheduler_kwargs': {'policy': 'ReduceLROnPlateau', 'patience': 5, 'factor': 0.5}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcessMatern32; iteration: 9/10; mean (std) r2=0.960 (0.020); model_params: {'epochs': 50, 'lr': 0.1, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': None, 'scheduler_kwargs': {}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcessMatern32; iteration: 10/10; mean (std) r2=0.905 (0.033); model_params: {'epochs': 200, 'lr': 0.01, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': <class 'torch.optim.lr_scheduler.ExponentialLR'>, 'scheduler_kwargs': {'gamma': 0.95}}
# DEBUG:autoemulate:Tuner found best params for model "GaussianProcessMatern32": {'epochs': 200, 'lr': 0.5, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': None, 'scheduler_kwargs': {}} with score: 0.995
# DEBUG:autoemulate:Running cross-validation for model "GaussianProcessMatern32" for "10" iterations
# DEBUG:autoemulate:Cross-validation for model "GaussianProcessMatern32" completed with test mean (std) R2 score: 0.996 (0.002), mean (std) RMSE score: 2.550 (0.597)
# INFO:autoemulate:Finished running Model: GaussianProcessMatern32
#
# INFO:autoemulate:Running Model: GaussianProcessMatern52: 4/11 (attempt 1/3)
# DEBUG:autoemulate:Running tuner for model "GaussianProcessMatern52"
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcessMatern52; iteration: 1/10; mean (std) r2=0.931 (0.029); model_params: {'epochs': 50, 'lr': 0.05, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': <class 'torch.optim.lr_scheduler.LRScheduler'>, 'scheduler_kwargs': {'policy': 'ReduceLROnPlateau', 'patience': 5, 'factor': 0.5}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcessMatern52; iteration: 2/10; mean (std) r2=0.975 (0.007); model_params: {'epochs': 100, 'lr': 0.05, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': None, 'scheduler_kwargs': {}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcessMatern52; iteration: 3/10; mean (std) r2=0.991 (0.004); model_params: {'epochs': 100, 'lr': 0.1, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': <class 'torch.optim.lr_scheduler.ExponentialLR'>, 'scheduler_kwargs': {'gamma': 0.9}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcessMatern52; iteration: 4/10; mean (std) r2=0.785 (0.045); model_params: {'epochs': 50, 'lr': 0.01, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': <class 'torch.optim.lr_scheduler.LRScheduler'>, 'scheduler_kwargs': {'policy': 'ReduceLROnPlateau', 'patience': 5, 'factor': 0.5}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcessMatern52; iteration: 5/10; mean (std) r2=0.967 (0.007); model_params: {'epochs': 100, 'lr': 0.05, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': <class 'torch.optim.lr_scheduler.LRScheduler'>, 'scheduler_kwargs': {'policy': 'ReduceLROnPlateau', 'patience': 5, 'factor': 0.5}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcessMatern52; iteration: 6/10; mean (std) r2=0.996 (0.002); model_params: {'epochs': 50, 'lr': 0.5, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': None, 'scheduler_kwargs': {}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcessMatern52; iteration: 7/10; mean (std) r2=0.990 (0.008); model_params: {'epochs': 100, 'lr': 0.1, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': <class 'torch.optim.lr_scheduler.ExponentialLR'>, 'scheduler_kwargs': {'gamma': 0.9}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcessMatern52; iteration: 8/10; mean (std) r2=0.858 (0.050); model_params: {'epochs': 100, 'lr': 0.01, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': <class 'torch.optim.lr_scheduler.LRScheduler'>, 'scheduler_kwargs': {'policy': 'ReduceLROnPlateau', 'patience': 5, 'factor': 0.5}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcessMatern52; iteration: 9/10; mean (std) r2=0.966 (0.013); model_params: {'epochs': 50, 'lr': 0.1, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': None, 'scheduler_kwargs': {}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcessMatern52; iteration: 10/10; mean (std) r2=0.995 (0.003); model_params: {'epochs': 100, 'lr': 0.5, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': <class 'torch.optim.lr_scheduler.LRScheduler'>, 'scheduler_kwargs': {'policy': 'ReduceLROnPlateau', 'patience': 5, 'factor': 0.5}}
# DEBUG:autoemulate:Tuner found best params for model "GaussianProcessMatern52": {'epochs': 50, 'lr': 0.5, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': None, 'scheduler_kwargs': {}} with score: 0.996
# DEBUG:autoemulate:Running cross-validation for model "GaussianProcessMatern52" for "10" iterations
# DEBUG:autoemulate:Cross-validation for model "GaussianProcessMatern52" completed with test mean (std) R2 score: 0.998 (0.001), mean (std) RMSE score: 2.104 (0.529)
# INFO:autoemulate:Finished running Model: GaussianProcessMatern52
#
# INFO:autoemulate:Running Model: GaussianProcessRBF: 5/11 (attempt 1/3)
# DEBUG:autoemulate:Running tuner for model "GaussianProcessRBF"
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: GaussianProcessRBF; iteration: 1/10; mean (std) r2=0.996 (0.001); model_params: {'epochs': 100, 'lr': 0.5, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': <class 'torch.optim.lr_scheduler.LRScheduler'>, 'scheduler_kwargs': {'policy': 'ReduceLROnPlateau', 'patience': 5, 'factor': 0.5}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# ...
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: EnsembleMLP; iteration: 6/10; mean (std) r2=-0.036 (0.058); model_params: {'n_emulators': 6, 'epochs': 200, 'layer_dims': [16, 8], 'lr': 0.2, 'batch_size': 16, 'weight_init': 'normal', 'scale': 0.1, 'bias_init': 'default', 'dropout_prob': 0.3, 'scheduler_cls': None, 'scheduler_kwargs': {}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: EnsembleMLP; iteration: 7/10; mean (std) r2=-0.049 (0.032); model_params: {'n_emulators': 6, 'epochs': 200, 'layer_dims': [64, 32, 16], 'lr': 0.5, 'batch_size': 32, 'weight_init': 'normal', 'scale': 1.0, 'bias_init': 'default', 'dropout_prob': 0.3, 'scheduler_cls': <class 'torch.optim.lr_scheduler.LRScheduler'>, 'scheduler_kwargs': {'policy': 'ReduceLROnPlateau', 'patience': 5, 'factor': 0.5}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: EnsembleMLP; iteration: 8/10; mean (std) r2=-0.041 (0.016); model_params: {'n_emulators': 6, 'epochs': 200, 'layer_dims': [64, 32, 16], 'lr': 0.01, 'batch_size': 32, 'weight_init': 'normal', 'scale': 1.0, 'bias_init': 'zeros', 'dropout_prob': 0.3, 'scheduler_cls': <class 'torch.optim.lr_scheduler.ExponentialLR'>, 'scheduler_kwargs': {'gamma': 0.9}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: EnsembleMLP; iteration: 9/10; mean (std) r2=0.210 (0.054); model_params: {'n_emulators': 6, 'epochs': 200, 'layer_dims': [16, 8], 'lr': 0.2, 'batch_size': 32, 'weight_init': 'default', 'scale': 1.0, 'bias_init': 'default', 'dropout_prob': 0.3, 'scheduler_cls': None, 'scheduler_kwargs': {}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: EnsembleMLP; iteration: 10/10; mean (std) r2=-0.010 (0.075); model_params: {'n_emulators': 2, 'epochs': 200, 'layer_dims': [16, 8], 'lr': 0.2, 'batch_size': 16, 'weight_init': 'default', 'scale': 0.1, 'bias_init': 'zeros', 'dropout_prob': 0.3, 'scheduler_cls': <class 'torch.optim.lr_scheduler.LRScheduler'>, 'scheduler_kwargs': {'policy': 'ReduceLROnPlateau', 'patience': 5, 'factor': 0.5}}
# DEBUG:autoemulate:Tuner found best params for model "EnsembleMLP": {'n_emulators': 8, 'epochs': 200, 'layer_dims': [8, 4], 'lr': 0.001, 'batch_size': 16, 'weight_init': 'default', 'scale': 1.0, 'bias_init': 'zeros', 'dropout_prob': None, 'scheduler_cls': <class 'torch.optim.lr_scheduler.LRScheduler'>, 'scheduler_kwargs': {'policy': 'ReduceLROnPlateau', 'patience': 5, 'factor': 0.5}} with score: 0.922
# DEBUG:autoemulate:Running cross-validation for model "EnsembleMLP" for "10" iterations
# DEBUG:autoemulate:Cross-validation for model "EnsembleMLP" completed with test mean (std) R2 score: 0.945 (0.016), mean (std) RMSE score: 12.231 (1.159)
# INFO:autoemulate:Finished running Model: EnsembleMLP
#
# INFO:autoemulate:Running Model: EnsembleMLPDropout: 11/11 (attempt 1/3)
# DEBUG:autoemulate:Running tuner for model "EnsembleMLPDropout"
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: EnsembleMLPDropout; iteration: 1/10; mean (std) r2=-0.025 (0.026); model_params: {'n_emulators': 8, 'epochs': 200, 'layer_dims': [64, 32, 16], 'lr': 0.1, 'batch_size': 16, 'weight_init': 'default', 'scale': 0.1, 'bias_init': 'zeros', 'dropout_prob': 0.3, 'scheduler_cls': <class 'torch.optim.lr_scheduler.LRScheduler'>, 'scheduler_kwargs': {'policy': 'ReduceLROnPlateau', 'patience': 5, 'factor': 0.5}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: EnsembleMLPDropout; iteration: 2/10; mean (std) r2=0.666 (0.061); model_params: {'n_emulators': 4, 'epochs': 200, 'layer_dims': [16, 8], 'lr': 0.1, 'batch_size': 32, 'weight_init': 'normal', 'scale': 0.1, 'bias_init': 'zeros', 'dropout_prob': 0.3, 'scheduler_cls': None, 'scheduler_kwargs': {}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: EnsembleMLPDropout; iteration: 3/10; mean (std) r2=0.635 (0.118); model_params: {'n_emulators': 4, 'epochs': 200, 'layer_dims': [8, 4], 'lr': 0.001, 'batch_size': 16, 'weight_init': 'default', 'scale': 0.1, 'bias_init': 'default', 'dropout_prob': 0.3, 'scheduler_cls': <class 'torch.optim.lr_scheduler.LRScheduler'>, 'scheduler_kwargs': {'policy': 'ReduceLROnPlateau', 'patience': 5, 'factor': 0.5}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: EnsembleMLPDropout; iteration: 4/10; mean (std) r2=-0.065 (0.032); model_params: {'n_emulators': 8, 'epochs': 200, 'layer_dims': [64, 32, 16], 'lr': 0.2, 'batch_size': 32, 'weight_init': 'normal', 'scale': 1.0, 'bias_init': 'zeros', 'dropout_prob': 0.3, 'scheduler_cls': <class 'torch.optim.lr_scheduler.ExponentialLR'>, 'scheduler_kwargs': {'gamma': 0.95}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: EnsembleMLPDropout; iteration: 5/10; mean (std) r2=-0.088 (0.114); model_params: {'n_emulators': 4, 'epochs': 100, 'layer_dims': [8, 4], 'lr': 0.2, 'batch_size': 32, 'weight_init': 'normal', 'scale': 1.0, 'bias_init': 'default', 'dropout_prob': 0.3, 'scheduler_cls': <class 'torch.optim.lr_scheduler.LRScheduler'>, 'scheduler_kwargs': {'policy': 'ReduceLROnPlateau', 'patience': 5, 'factor': 0.5}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: EnsembleMLPDropout; iteration: 6/10; mean (std) r2=0.837 (0.037); model_params: {'n_emulators': 4, 'epochs': 100, 'layer_dims': [64, 32, 16], 'lr': 0.01, 'batch_size': 32, 'weight_init': 'normal', 'scale': 0.1, 'bias_init': 'default', 'dropout_prob': 0.3, 'scheduler_cls': <class 'torch.optim.lr_scheduler.ExponentialLR'>, 'scheduler_kwargs': {'gamma': 0.95}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: EnsembleMLPDropout; iteration: 7/10; mean (std) r2=-0.022 (0.012); model_params: {'n_emulators': 4, 'epochs': 200, 'layer_dims': [64, 32, 16], 'lr': 0.2, 'batch_size': 32, 'weight_init': 'default', 'scale': 1.0, 'bias_init': 'default', 'dropout_prob': 0.3, 'scheduler_cls': <class 'torch.optim.lr_scheduler.LRScheduler'>, 'scheduler_kwargs': {'policy': 'ReduceLROnPlateau', 'patience': 5, 'factor': 0.5}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: EnsembleMLPDropout; iteration: 8/10; mean (std) r2=-0.046 (0.033); model_params: {'n_emulators': 8, 'epochs': 200, 'layer_dims': [64, 32, 16], 'lr': 0.2, 'batch_size': 32, 'weight_init': 'default', 'scale': 1.0, 'bias_init': 'zeros', 'dropout_prob': 0.3, 'scheduler_cls': <class 'torch.optim.lr_scheduler.ExponentialLR'>, 'scheduler_kwargs': {'gamma': 0.9}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: EnsembleMLPDropout; iteration: 9/10; mean (std) r2=-48.071 (46.309); model_params: {'n_emulators': 2, 'epochs': 100, 'layer_dims': [32, 16], 'lr': 0.001, 'batch_size': 16, 'weight_init': 'normal', 'scale': 1.0, 'bias_init': 'zeros', 'dropout_prob': 0.3, 'scheduler_cls': <class 'torch.optim.lr_scheduler.LRScheduler'>, 'scheduler_kwargs': {'policy': 'ReduceLROnPlateau', 'patience': 5, 'factor': 0.5}}
# DEBUG:autoemulate:Cross-validation parameters: KFold(n_splits=5, random_state=None, shuffle=True)
# DEBUG:autoemulate:Cross-validation split 0: 92 train samples, 24 validation samples
# DEBUG:autoemulate:Cross-validation split 1: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 2: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 3: 93 train samples, 23 validation samples
# DEBUG:autoemulate:Cross-validation split 4: 93 train samples, 23 validation samples
# DEBUG:autoemulate:tuning model: EnsembleMLPDropout; iteration: 10/10; mean (std) r2=-3.378 (6.693); model_params: {'n_emulators': 4, 'epochs': 200, 'layer_dims': [64, 32, 16], 'lr': 0.5, 'batch_size': 16, 'weight_init': 'normal', 'scale': 1.0, 'bias_init': 'default', 'dropout_prob': 0.3, 'scheduler_cls': None, 'scheduler_kwargs': {}}
# DEBUG:autoemulate:Tuner found best params for model "EnsembleMLPDropout": {'n_emulators': 4, 'epochs': 100, 'layer_dims': [64, 32, 16], 'lr': 0.01, 'batch_size': 32, 'weight_init': 'normal', 'scale': 0.1, 'bias_init': 'default', 'dropout_prob': 0.3, 'scheduler_cls': <class 'torch.optim.lr_scheduler.ExponentialLR'>, 'scheduler_kwargs': {'gamma': 0.95}} with score: 0.837
# DEBUG:autoemulate:Running cross-validation for model "EnsembleMLPDropout" for "10" iterations
# DEBUG:autoemulate:Cross-validation for model "EnsembleMLPDropout" completed with test mean (std) R2 score: 0.851 (0.022), mean (std) RMSE score: 24.350 (3.510)
# INFO:autoemulate:Finished running Model: EnsembleMLPDropout
#
# DEBUG:autoemulate:('Comparison results:\nBest Model: GaussianProcess, x transforms: [StandardizeTransform()], y transforms: [StandardizeTransform()]', "Best params: {'mean_module_fn': <function constant_mean at 0x7e6040505440>, 'covar_module_fn': <function matern_5_2_plus_rq at 0x7e6040505260>, 'epochs': 50, 'lr': 0.5, 'likelihood_cls': <class 'gpytorch.likelihoods.multitask_gaussian_likelihood.MultitaskGaussianLikelihood'>, 'scheduler_cls': <class 'torch.optim.lr_scheduler.ExponentialLR'>, 'scheduler_kwargs': {'gamma': 0.9}}, R2 score: 0.999, RMSE score: 1.568")

# %%
# Create summary list for each emulator
summary = [] # initialises empty array
for r in ae.results: # loops over all emulator runs
      emulator_results = [res for res in ae.results if res.model_name == r.model_name] # looks at all results for ONE emulator
      best_run = min(emulator_results, key=lambda res: res.rmse_test) # takes run with minimum rmse (best)
      summary.append((best_run.model_name, best_run.r2_test, best_run.rmse_test, best_run.model)) # adds best run to summary

# %%
# Print Key results
for name, r2, rmse, model in summary:
    print(f"{name:25} R²={r2:.3f}, RMSE={rmse:.3f}")
# Out:
# GaussianProcess           R²=0.999, RMSE=1.568
# GaussianProcessCorrelated R²=0.997, RMSE=2.616
# GaussianProcessMatern32   R²=0.996, RMSE=2.550
# GaussianProcessMatern52   R²=0.998, RMSE=2.104
# GaussianProcessRBF        R²=0.998, RMSE=1.978
# RadialBasisFunctions      R²=0.976, RMSE=5.517
# RandomForest              R²=0.847, RMSE=20.060
# PolynomialRegression      R²=0.973, RMSE=6.223
# MLP                       R²=0.946, RMSE=12.318
# EnsembleMLP               R²=0.945, RMSE=12.231
# EnsembleMLPDropout        R²=0.851, RMSE=24.350

# %% [markdown]
# From the summary we can see that Gaussian process models are outperforming the other emulators, across several kernels. AutoEmulate also has a function to choose the best emulator for the training data, we use it below to predict the .

# %%
# best model (chooses best emulator run over all emulator types)
best_result = ae.best_result()
best_model = best_result.model
y_pred = best_model.predict(x_test).mean

# --- Plot predicted vs true for each output dimension ---
y_true = y_test.detach().numpy() if isinstance(y, torch.Tensor) else y
n_outputs = y_true.shape[1]

for i in range(n_outputs):
    plt.figure(figsize=(6,6))
    plt.scatter(y_true[:, i], y_pred[:, i])
    plt.plot([y_true[:, i].min(), y_true[:, i].max()],
             [y_true[:, i].min(), y_true[:, i].max()],
             'r--', lw=2)  # identity line
    plt.xlabel("True Output")
    plt.ylabel("Predicted Output")
    plt.title(f"Output {i+1}: Predicted vs True")
    plt.grid(True)
    plt.show()

# %% [markdown]
# # Bonus exercise
#
# Use the autoemulate best emulator and SALib to generate sensitivity analysis for both outputs.

# %%
##### from SALib.sample import saltelli
from SALib.sample import saltelli
from SALib.analyze import sobol
from SALib.test_functions import Ishigami
import numpy as np


nDim = x_train.shape[1] # Number of input dimensions
boundsMaxMin = [] # Initialise max-min bounds
for i in range(nDim): # Calculates the max and min bounds of the parameters
    boundsMaxMin.append([np.min(x_train[:,i].detach().numpy()),np.max(x_train[:,i].detach().numpy())])
    print(boundsMaxMin[i])

# Define the GSA problem
problem = {
    'num_vars': nDim,
    'names': x_labels.values.squeeze(),
    'bounds': boundsMaxMin
}

# Generate samples via a saltelli sample
param_values = saltelli.sample(problem, 1024)

data1 = torch.tensor(param_values).float() # Convert to torch tensor for prediction

Ymean=best_model.predict(data1).mean #use the best emulator to predict the f at the sampled parameter values

# Calculate the sobol Indices and save the outputs for plotting

Si = []
nMod = y_all.shape[1]
for i in range(nMod):
    Si.append(sobol.analyze(problem, Ymean[:,i].detach().numpy(), print_to_console=True,calc_second_order=True))

Si_first=np.zeros((nDim,nMod))
Si_total=np.zeros((nDim,nMod))
for i in range(nMod):

    total_Si, first_Si, second_Si = Si[i].to_df()
    Si_first[:,i] =  first_Si.iloc[:,0]
    Si_total[:,i] =  total_Si.iloc[:,0]
# Out:
# [np.float32(0.381556), np.float32(0.798064)]
# [np.float32(0.201916), np.float32(0.499332)]
# [np.float32(1.23875), np.float32(8.37162)]
# [np.float32(0.303523), np.float32(1.02852)]
# [np.float32(0.200934), np.float32(0.498921)]
# [np.float32(1.00695), np.float32(5.65982)]
#                      ST   ST_conf
# CV_ventricles  0.000062  0.000012
# k_ventricles   0.000030  0.000005
# k_FEC          0.000083  0.000014
# CV_atria       0.923419  0.054204
# k_atria        0.018931  0.001927
# k_BB           0.064185  0.007372
#                      S1   S1_conf
# CV_ventricles  0.000047  0.000706
# k_ventricles  -0.000042  0.000466
# k_FEC         -0.000016  0.000685
# CV_atria       0.914365  0.078028
# k_atria        0.016402  0.011278
# k_BB           0.058289  0.021713
#                                          S2   S2_conf
# (CV_ventricles, k_ventricles)  3.320270e-05  0.001052
# (CV_ventricles, k_FEC)         3.738661e-05  0.001054
# (CV_ventricles, CV_atria)      2.115056e-04  0.001169
# (CV_ventricles, k_atria)       8.687394e-05  0.001032
# (CV_ventricles, k_BB)         -7.864980e-05  0.001149
# (k_ventricles, k_FEC)         -3.152884e-05  0.000644
# (k_ventricles, CV_atria)       7.601390e-05  0.000658
# (k_ventricles, k_atria)       -2.464118e-07  0.000647
# (k_ventricles, k_BB)          -2.322526e-05  0.000612
# (k_FEC, CV_atria)              1.298275e-04  0.001459
# (k_FEC, k_atria)               5.107667e-05  0.001206
# (k_FEC, k_BB)                  1.193540e-04  0.001258
# (CV_atria, k_atria)            3.044030e-03  0.113611
# (CV_atria, k_BB)               6.156421e-03  0.121927
# (k_atria, k_BB)                4.049586e-04  0.019064
#                      ST   ST_conf
# CV_ventricles  0.825717  0.065065
# k_ventricles   0.095942  0.011181
# k_FEC          0.085505  0.012737
# CV_atria       0.000283  0.000059
# k_atria        0.000101  0.000021
# k_BB           0.000086  0.000013
#                      S1   S1_conf
# CV_ventricles  0.818885  0.065855
# k_ventricles   0.091483  0.031362
# k_FEC          0.080748  0.030466
# CV_atria       0.000189  0.001457
# k_atria        0.000416  0.000794
# k_BB          -0.000256  0.000760
#                                      S2   S2_conf
# (CV_ventricles, k_ventricles)  0.002011  0.092593
# (CV_ventricles, k_FEC)         0.000738  0.091369
# (CV_ventricles, CV_atria)     -0.001655  0.084939
# (CV_ventricles, k_atria)      -0.001652  0.084917
# (CV_ventricles, k_BB)         -0.001138  0.084806
# (k_ventricles, k_FEC)          0.001179  0.045034
# (k_ventricles, CV_atria)       0.000122  0.041960
# (k_ventricles, k_atria)       -0.000085  0.042097
# (k_ventricles, k_BB)           0.000126  0.042047
# (k_FEC, CV_atria)              0.001066  0.047689
# (k_FEC, k_atria)               0.000961  0.047861
# (k_FEC, k_BB)                  0.000933  0.047833
# (CV_atria, k_atria)           -0.000817  0.002278
# (CV_atria, k_BB)              -0.000851  0.002282
# (k_atria, k_BB)               -0.000574  0.001219

# %%
# Plot the outcome

inputs = x_all.columns.tolist()
outputs = y_all.columns.tolist()
fig, ax = plt.subplots()
im = ax.imshow(Si_first[0:28],cmap='magma_r',vmin=0,vmax=1)

ax.set_xticks(np.arange(len(outputs)),labels=outputs)
ax.set_yticks(np.arange(len(inputs)), labels=inputs)
plt.setp(ax.get_xticklabels(), rotation=60, ha="right",
         rotation_mode="anchor");

plt.colorbar(im,fraction=0.015, pad=0.04)
